# %% [markdown]
# <a href="https://colab.research.google.com/github/45bw6tv8zr-hub/gis-project-portfolio-geo441c/blob/main/GEO441_Week1_Koski_Gianna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **GEO 441/541C Week 1 Assignment: Introduction to ArcGIS Pro GUI**

# %% [markdown]
# Created by Gianna Koski
# 01/30/2026

# %% [markdown]
# ### **Get ready to start**

# %% [markdown]
# ### **Create my first map using ArcGIS Pro**
#
# 1. **Instructions**
#    - Follow mapping instructions from [this Canvas file](https://miamioh.instructure.com/courses/246872/assignments/3381520)
#    - Mapping instructions are adapted from *Lab 1: Introduction to ArcGIS Pro* in [GIS Fundamentals Resources page](https://www.gisfundamentals.org/resources)
#
# 2. **Share map**
#    - Upload the PNG file exported from ArcGIS Pro to my Google Drive folder for Week 1 assignment
#    - Change Share privilege to make this file viewable by anyone with a link
#    - Copy the sharable link
#
# 3. **Obtain a sharable link**
#
#    - The default link I get for this PNG file is listed below but it cannot be directly used in Notebook to show the picture correctly
# https://drive.google.com/file/d/1etve3_V21Nj5aFIr2uTRfkWci0BRKBxD/view?usp=sharing
#   - I made some changes to the default sharable link:
#     - Keep the **`1A2B3C4D5E6F7G8H9I0J`** part because this is the unique file ID for the picture
#     - Deleted **`/view?usp=sharing`** at the end of the link
#     - Replaced **`/file/d/`** with **`/uc?export=view&id=`**
#    - Here is an example I referred to:
#     - Default sharable link
#
# https://drive.google.com/file/d/1etve3_V21Nj5aFIr2uTRfkWci0BRKBxD/view?usp=sharing
#    - The direct link for view from this example would be
#
# https://drive.google.com/uc?export=view&id=1etve3_V21Nj5aFIr2uTRfkWci0BRKBxD
#   - The link below is the correct one I need to use in the next section
#
# https://drive.google.com/uc?export=view&id=1etve3_V21Nj5aFIr2uTRfkWci0BRKBxD
#
#
# 4. **Map**
#
#    ![Map](https://drive.google.com/uc?export=view&id=1etve3_V21Nj5aFIr2uTRfkWci0BRKBxD) <!-- Example Image Placeholder -->

# %% [markdown]
# ### **Reflection on my first experience with ArcGIS Pro**
#
# - Overall, I spent 1-2 hours to finish creating my first map
# - Here is a table showing things that I feel excited and challenging in my first experience working in ArcGIS Pro
#
# | Things I'm excited about      | Things challenging for me  |
# | ----------------------------- | -------------------------- |
# | Using a more advanced maping tool     | Navigating ArcGIS Pro  |
# | Visually seeing data     | Remembering the steps     |
# | Advancing my GIS skills      | working through problems   |
#
# - Here is how I rate my first experience working in ArcGIS Pro
#   - Data important and management
#     - [I used data import and management to unzip the file and bring the datasets into ArcGIS pro. I then put the layers I needed, Lakes and Roads, into the map. This helped me understand why its so important to keep data organized to make the map-making process smoother.]
#   - Map creation and annotation
#     - [While creating my map, I made sure the layers were placed in an order that made since while keeping the map visauly appealing. In specidic, I made sure the roads layers were over the lakes so that the birdges wernt hidden. Along with that, I made sure the north arrow, scale, title, and lenged were balenceing out the rest of the map.]
#   - Navigate the software using its GUI
#     - [At first it was confusing becuase I was not used to the layout, but as i kept working I b egan to learn where everything was. As I continue to use ArcGIS, I am excited to learn more and get more comfortable.]

# %% [markdown]
# ### **Save and share this notebook**
#
# - I made this notebook viewable by anyone with the link
# ![Screenshot 2026-02-05 at 6.04.42 PM.png](data:image/png;base64,...)
# ![Share Notebook](PASTE_IMAGE_LINK_HERE)
#
# - Then I copied [this link](https://colab.research.google.com/drive/1pSlN1EM6FFc3fcozjE8OenNbYru1amUW?usp=sharing) as my submission to Assignment Week 1

# %% [markdown]
# ### **Reference**
#
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
